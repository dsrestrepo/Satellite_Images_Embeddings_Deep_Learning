# %% [markdown]
# ## Import libraries

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# To install pickle:
# !pip install pickle5
# To install pandas:
# !pip install pandas
# To install numpy:
# !pip install numpy

# %%
# For pickle files:
import pickle
# For csv files
import pandas as pd
# For arrays
import numpy as np

# %%
# to install epiweeks in python:
# !pip install epiweeks

# %%
# For Epiweek:
from epiweeks import Week, Year
from datetime import date

# %% [markdown]
# # 1. Read pickle file

# %%
# Function to read file:
def read_pickle(file_path):
    infile = open(file_path,'rb')
    file = pickle.load(infile)
    infile.close()
    print(f'The file has a shape: {file.shape} and class: {type(file)}')
    return file

# %% [markdown]
# ## Examples:

# %% [markdown]
# ### Example 1

# %%
# Path to picke file:
# file_path = 'path_to_pickle.pkl'
file_path = 'Embeddings/features_resnet50.pkl'

# Read the file:
file = read_pickle(file_path)
# Out:
# The file has a shape: (164, 100) and class: <class 'numpy.ndarray'>

# %% [markdown]
# ### Example 2

# %%
# Path to picke file:
# file_path = 'path_to_pickle.pkl'
file_path = 'Embeddings/features_transformer.pkl'

# Read the file:
file = read_pickle(file_path)
# Out:
# The file has a shape: (164, 100) and class: <class 'numpy.ndarray'>

# %% [markdown]
# ## Numpy array to pandas dataframe:

# %%
# Function to split one column of features into multiple columns:
def split_columns(df):
    df_aux = pd.DataFrame(df['features'].tolist())
    df_aux = pd.concat( [df['Date'], df_aux], axis=1)
    return df_aux


# Function to genearte the dataframe from features and date arrays:
def generate_dataframe(features, dates):
    features_df = pd.DataFrame(columns=['Date', 'features'])
    for i in range(len(features)):
        image_features = features[i]
        date = dates[i]
        features_df = features_df.append({'Date': date, 'features': image_features}, ignore_index=True )
    # new df from the column of lists
    features_df = split_columns(features_df)
    return features_df

# %% [markdown]
# ## Examples:

# %% [markdown]
# ### Example 1:

# %%
# Read the date:

# Path to date
dates_path = 'Embeddings/dates.pkl'
# Read the file:
dates = read_pickle(dates_path)
# Out:
# The file has a shape: (165,) and class: <class 'numpy.ndarray'>

# %%
# Read the features:

# Path to picke file:
file_path = 'Embeddings/features_resnet50.pkl'
# Read the file:
file = read_pickle(file_path)
# Out:
# The file has a shape: (164, 100) and class: <class 'numpy.ndarray'>

# %%
# Genearate dataframe
features_df = generate_dataframe(file, dates)

# Show features as dataframe:
features_df.head()
# Out:
#          Date         0         1         2         3         4         5  \
# 0  2015-11-01 -0.086982  0.288081 -0.006342  0.208007  0.266013 -0.859696
# 1  2015-11-08  0.047980  0.196725  0.042814  0.134543  0.370102 -0.990212
# 2  2015-11-15  0.033984  0.103946  0.058474  0.127122  0.309244 -0.992553
# 3  2015-11-22 -0.048743  0.161994 -0.007947  0.187336  0.387438 -0.982925
# 4  2015-11-29 -0.173518  0.013973  0.100720  0.073034  0.060532 -0.799869
#
#           6         7         8  ...        90        91        92        93  \
# 0  0.074751  0.112848 -0.001884  ...  0.262575  0.110694 -0.126360 -0.053719
# 1 -0.021948  0.094639  0.055113  ...  0.175898  0.260473 -0.164818  0.075305
# 2 -0.022212  0.147466  0.029719  ...  0.124701  0.113317 -0.198573 -0.076236
# 3  0.004363  0.063091  0.083177  ...  0.180346  0.149084 -0.086722  0.013918
# 4  0.141367  0.056267 -0.050752  ...  0.032416 -0.235834 -0.217754  0.030347
#
#          94        95        96        97        98        99
# 0 -0.226204 -0.082629 -0.174591 -0.084881 -0.066012  0.071893
# 1 -0.058506  0.035748 -0.139905 -0.097720 -0.018967  0.096694
# 2 -0.017778 -0.029593 -0.077974  0.015587 -0.033545  0.075111
# 3 -0.091514  0.082734 -0.102815  0.099621 -0.000714  0.047569
# 4 -0.032033  0.027889 -0.310983  0.257912  0.004529  0.081347
#
# [5 rows x 101 columns]

# %%
features_df.to_csv('Embeddings/features_resnet50.csv', index=False)

# %% [markdown]
# ### Example 2:

# %%
# Read the features:

# Path to picke file:
file_path = 'Embeddings/features_transformer.pkl'
# Read the file:
file = read_pickle(file_path)
# Out:
# The file has a shape: (164, 100) and class: <class 'numpy.ndarray'>

# %%
# Genearate dataframe
features_df = generate_dataframe(file, dates)

# Show features as dataframe:
features_df.head()
# Out:
#          Date         0         1         2         3         4         5  \
# 0  2015-11-01  0.387164  0.403747  0.008258  0.185946 -0.023333  0.175896
# 1  2015-11-08  0.386666  0.403197  0.009119  0.186291 -0.022466  0.174298
# 2  2015-11-15  0.386666  0.403197  0.009119  0.186291 -0.022466  0.174298
# 3  2015-11-22  0.386666  0.403197  0.009119  0.186291 -0.022466  0.174298
# 4  2015-11-29  0.386666  0.403197  0.009119  0.186291 -0.022466  0.174298
#
#           6         7         8  ...        90        91        92        93  \
# 0  0.349484  0.335330 -0.110036  ... -0.001924  1.179506  0.642817 -0.005041
# 1  0.349471  0.335451 -0.109947  ... -0.002548  1.178966  0.643421 -0.004440
# 2  0.349471  0.335451 -0.109947  ... -0.002548  1.178966  0.643421 -0.004440
# 3  0.349471  0.335451 -0.109947  ... -0.002548  1.178966  0.643421 -0.004440
# 4  0.349471  0.335451 -0.109947  ... -0.002548  1.178966  0.643421 -0.004440
#
#          94        95        96        97        98        99
# 0 -0.533648 -0.636882  0.004286  0.052736  0.106446 -0.345410
# 1 -0.535207 -0.636864  0.004112  0.050820  0.106349 -0.345483
# 2 -0.535207 -0.636864  0.004112  0.050820  0.106349 -0.345483
# 3 -0.535207 -0.636864  0.004112  0.050820  0.106349 -0.345483
# 4 -0.535207 -0.636864  0.004112  0.050820  0.106349 -0.345483
#
# [5 rows x 101 columns]

# %%
features_df.to_csv('Embeddings/features_transformer.csv', index=False)

# %% [markdown]
# # 2. Read csv file

# %% [markdown]
# ## Examples:

# %% [markdown]
# ### Example 1:

# %%
# Path to csv file:
# file_path = 'path_to_csv.csv'
file_path = 'Embeddings/pca_medellin_100features.csv'

# Read csv file
file = pd.read_csv(file_path)

# Show the dataframe:
# Number of rows to show:
rows = 5 
# show:
file.head(rows)
# Out:
#          Date           0           1          2          3          4  \
# 0  2015-11-01   98.435754  108.962228 -40.915729  39.468939  47.325778
# 1  2015-11-08   98.435754  108.962228 -40.915729  39.468939  47.325778
# 2  2015-11-15 -149.578506  118.675591 -28.032221 -37.096690  -3.305299
# 3  2015-11-22 -149.578506  118.675591 -28.032221 -37.096690  -3.305299
# 4  2015-11-29  -28.099436   34.715737  47.153387 -50.761985 -63.137078
#
#            5           6           7          8  ...         90         91  \
# 0  70.472168  187.431726 -229.801740  43.888213  ...   0.587965  -0.365837
# 1  70.472168  187.431726 -229.801740  43.888213  ...   0.587965  -0.365837
# 2 -67.746083   37.584909  -11.838416 -15.613838  ... -13.746142  13.683615
# 3 -67.746083   37.584909  -11.838416 -15.613838  ... -13.746142  13.683615
# 4 -58.088638   -6.508121   18.149721 -29.781310  ...  -6.670381  -5.520467
#
#          92        93         94        95         96         97         98  \
# 0 -2.923909  0.096117  -0.608161  0.119047   1.095555  -1.305447  -1.034465
# 1 -2.923909  0.096117  -0.608161  0.119047   1.095555  -1.305447  -1.034465
# 2 -1.131025 -3.349845 -10.681103 -6.437450  12.024817  12.829025  12.699458
# 3 -1.131025 -3.349845 -10.681103 -6.437450  12.024817  12.829025  12.699458
# 4 -4.101447  1.232668  -2.903102  2.551955  -3.338012  -5.490846  -2.383766
#
#          99
# 0 -0.486601
# 1 -0.486601
# 2  0.475610
# 3  0.475610
# 4 -1.712792
#
# [5 rows x 101 columns]

# %% [markdown]
# ### Example 2

# %%
# Path to csv file:
# file_path = 'path_to_csv.csv'
file_path = 'Embeddings/embeddings_medellin_100features.csv'

# Read csv file
file = pd.read_csv(file_path)

# Show the dataframe:
# Number of rows to show:
rows = 5 
# show:
file.head(rows)
# Out:
#          Date         0         1         2         3         4         5  \
# 0  2015-11-01 -0.773164  0.409429 -1.967424 -0.194265  1.589418 -0.806473
# 1  2015-11-08 -0.375792  1.282191 -1.769311 -1.768404  0.960811 -1.401841
# 2  2015-11-15  0.270060  1.896669  0.160804  0.100467 -1.593640 -0.673158
# 3  2015-11-22 -1.050474 -0.492467 -3.057118 -2.102062  0.290074 -1.837421
# 4  2015-11-29  0.277096 -0.177303  1.520242  1.147505  0.999619  0.343843
#
#           6         7         8  ...        90        91        92        93  \
# 0  3.013131 -0.131107 -1.274766  ...  1.858297 -1.143137 -0.012872  2.545450
# 1 -0.138934  0.260522 -1.184208  ...  1.427782 -2.927658  0.504012 -0.062580
# 2  0.158351  1.709716 -0.976310  ...  1.151502 -1.066319  0.433531  0.623669
# 3  0.771637  0.883183  0.827531  ...  1.586739 -0.414671 -0.480104 -1.629912
# 4  1.057434  1.925118  0.395960  ...  1.060054 -0.819456 -0.657092  0.556108
#
#          94        95        96        97        98        99
# 0 -1.408913  2.835881 -4.650385  2.829885 -3.892387 -2.027068
# 1  3.175248 -1.147623 -2.653756  2.155063 -1.433320 -1.319588
# 2  1.678527 -2.044615  0.735826  1.307580 -0.059874 -0.276768
# 3  3.934243  2.386098 -1.041708  0.388762  0.855838 -1.768747
# 4  3.519002 -1.769988 -2.901545  0.582610  3.461969 -1.540928
#
# [5 rows x 101 columns]

# %% [markdown]
# ## CSV file to numpy array and dictionary:

# %%
# Function to generate:
# 1. Numpy array of features
# 2. Dictionary of key = date and value = features of image the in that date:
def get_embeddings_array(df):
    embeddings_list = np.array(df.iloc[:,1:])
    embeddings_date = np.array(df.iloc[:,0])
    embeddings_dict = dict()
    for date, embedding in zip(embeddings_date, embeddings_list):
        embeddings_dict[date] = embedding
        
    print(f'Array of shape: {embeddings_list.shape} and class: {type(embeddings_list)} generated!')
    print(f'Dictionary of class: {type(embeddings_dict)}, with keys = dates and values = features generated!')
    return embeddings_dict, embeddings_list

# %% [markdown]
# ## Examples:

# %% [markdown]
# ### Example 1:

# %%
# Path to csv file:
file_path = 'Embeddings/pca_medellin_100features.csv'
# Read csv file
features_df = pd.read_csv(file_path)

features_dictionary, features_array = get_embeddings_array(features_df)
# Out:
# Array of shape: (165, 100) and class: <class 'numpy.ndarray'> generated!
# Dictionary of class: <class 'dict'>, with keys = dates and values = features generated!

# %% [markdown]
# ### Example 2:

# %%
# Path to csv file:
file_path = 'Embeddings/embeddings_medellin_200features.csv'
# Read csv file
features_df = pd.read_csv(file_path)

features_dictionary, features_array = get_embeddings_array(features_df)
# Out:
# Array of shape: (165, 200) and class: <class 'numpy.ndarray'> generated!
# Dictionary of class: <class 'dict'>, with keys = dates and values = features generated!

# %% [markdown]
# # 3. Convert dates to epiweek

# %%
def getEpiweek(date_str):
    date_ls = date_str.split('-')
    week_date = date(int(date_ls[0]), int(date_ls[1]), int(date_ls[2]))
    week = Week.fromdate(week_date)
    return week

# %%
def dates_to_epiweek(dates_array):
    epiweeks_array = list()
    for date in dates_array:
        epiweek = getEpiweek(date)
        epiweeks_array.append(epiweek)
    epiweeks_array = np.array(epiweeks_array)
    print(f'The array with epiweeks of shape: {epiweeks_array.shape} and class: {type(epiweeks_array)} was generated!')
    return epiweeks_array

# %% [markdown]
# ## Examples

# %% [markdown]
# ### Example 1
# ###### Part 1: Using the pickle file with dates to generate an epiweek array:

# %%
# Read the date:

# Path to date
dates_path = 'Embeddings/dates.pkl'
# Read the file:
dates = read_pickle(dates_path)
# Out:
# The file has a shape: (165,) and class: <class 'numpy.ndarray'>

# %%
# Convert dates to epiweeks
epiweeks_array = dates_to_epiweek(dates)
# Out:
# The array with epiweeks of shape: (165,) and class: <class 'numpy.ndarray'> was generated!

# %% [markdown]
# ### Example 1
#
# ###### Part 2: Using the array of epiweeks create to generate a dataframe with features and epiweek:

# %%
# Read the features:

# Path to picke file:
file_path = 'Embeddings/features100_vae.pkl'
# Read the file:
file = read_pickle(file_path)
# Out:
# The file has a shape: (165, 100) and class: <class 'numpy.ndarray'>

# %%
# Genearate dataframe
features_df = generate_dataframe(file, epiweeks_array)

# Show features as dataframe:
features_df.head()
# Out:
#      Date         0         1         2         3         4         5  \
# 0  201544 -0.773164  0.409429 -1.967424 -0.194265  1.589418 -0.806473
# 1  201545 -0.375792  1.282191 -1.769311 -1.768404  0.960811 -1.401841
# 2  201546  0.270060  1.896669  0.160804  0.100467 -1.593640 -0.673158
# 3  201547 -1.050474 -0.492467 -3.057118 -2.102062  0.290074 -1.837421
# 4  201548  0.277096 -0.177303  1.520242  1.147505  0.999619  0.343843
#
#           6         7         8  ...        90        91        92        93  \
# 0  3.013131 -0.131107 -1.274766  ...  1.858297 -1.143137 -0.012872  2.545450
# 1 -0.138934  0.260522 -1.184208  ...  1.427782 -2.927658  0.504012 -0.062580
# 2  0.158351  1.709716 -0.976310  ...  1.151502 -1.066319  0.433531  0.623669
# 3  0.771637  0.883183  0.827531  ...  1.586739 -0.414671 -0.480104 -1.629912
# 4  1.057434  1.925118  0.395960  ...  1.060054 -0.819456 -0.657092  0.556108
#
#          94        95        96        97        98        99
# 0 -1.408913  2.835881 -4.650385  2.829885 -3.892387 -2.027068
# 1  3.175248 -1.147623 -2.653756  2.155063 -1.433320 -1.319588
# 2  1.678527 -2.044615  0.735826  1.307580 -0.059874 -0.276768
# 3  3.934243  2.386098 -1.041708  0.388762  0.855838 -1.768747
# 4  3.519002 -1.769988 -2.901545  0.582610  3.461969 -1.540928
#
# [5 rows x 101 columns]

# %% [markdown]
# ### Example 2
# ###### Convert the column date from a csv file to epiweeks:

# %%
# Path to csv file:
file_path = 'Embeddings/embeddings_medellin_100features.csv'

# Read csv file
file = pd.read_csv(file_path)

# Show the dataframe before apply the function:
# Number of rows to show:
rows = 5 
# show:
file.head(rows)
# Out:
#          Date         0         1         2         3         4         5  \
# 0  2015-11-01 -0.773164  0.409429 -1.967424 -0.194265  1.589418 -0.806473
# 1  2015-11-08 -0.375792  1.282191 -1.769311 -1.768404  0.960811 -1.401841
# 2  2015-11-15  0.270060  1.896669  0.160804  0.100467 -1.593640 -0.673158
# 3  2015-11-22 -1.050474 -0.492467 -3.057118 -2.102062  0.290074 -1.837421
# 4  2015-11-29  0.277096 -0.177303  1.520242  1.147505  0.999619  0.343843
#
#           6         7         8  ...        90        91        92        93  \
# 0  3.013131 -0.131107 -1.274766  ...  1.858297 -1.143137 -0.012872  2.545450
# 1 -0.138934  0.260522 -1.184208  ...  1.427782 -2.927658  0.504012 -0.062580
# 2  0.158351  1.709716 -0.976310  ...  1.151502 -1.066319  0.433531  0.623669
# 3  0.771637  0.883183  0.827531  ...  1.586739 -0.414671 -0.480104 -1.629912
# 4  1.057434  1.925118  0.395960  ...  1.060054 -0.819456 -0.657092  0.556108
#
#          94        95        96        97        98        99
# 0 -1.408913  2.835881 -4.650385  2.829885 -3.892387 -2.027068
# 1  3.175248 -1.147623 -2.653756  2.155063 -1.433320 -1.319588
# 2  1.678527 -2.044615  0.735826  1.307580 -0.059874 -0.276768
# 3  3.934243  2.386098 -1.041708  0.388762  0.855838 -1.768747
# 4  3.519002 -1.769988 -2.901545  0.582610  3.461969 -1.540928
#
# [5 rows x 101 columns]

# %%
# Change the date in column date to epiweek:
file['Date'] = file['Date'].apply(getEpiweek)

# Show the dataframe after:
# Number of rows to show:
rows = 5 
# show:
file.head(rows)
# Out:
#      Date         0         1         2         3         4         5  \
# 0  201544 -0.773164  0.409429 -1.967424 -0.194265  1.589418 -0.806473
# 1  201545 -0.375792  1.282191 -1.769311 -1.768404  0.960811 -1.401841
# 2  201546  0.270060  1.896669  0.160804  0.100467 -1.593640 -0.673158
# 3  201547 -1.050474 -0.492467 -3.057118 -2.102062  0.290074 -1.837421
# 4  201548  0.277096 -0.177303  1.520242  1.147505  0.999619  0.343843
#
#           6         7         8  ...        90        91        92        93  \
# 0  3.013131 -0.131107 -1.274766  ...  1.858297 -1.143137 -0.012872  2.545450
# 1 -0.138934  0.260522 -1.184208  ...  1.427782 -2.927658  0.504012 -0.062580
# 2  0.158351  1.709716 -0.976310  ...  1.151502 -1.066319  0.433531  0.623669
# 3  0.771637  0.883183  0.827531  ...  1.586739 -0.414671 -0.480104 -1.629912
# 4  1.057434  1.925118  0.395960  ...  1.060054 -0.819456 -0.657092  0.556108
#
#          94        95        96        97        98        99
# 0 -1.408913  2.835881 -4.650385  2.829885 -3.892387 -2.027068
# 1  3.175248 -1.147623 -2.653756  2.155063 -1.433320 -1.319588
# 2  1.678527 -2.044615  0.735826  1.307580 -0.059874 -0.276768
# 3  3.934243  2.386098 -1.041708  0.388762  0.855838 -1.768747
# 4  3.519002 -1.769988 -2.901545  0.582610  3.461969 -1.540928
#
# [5 rows x 101 columns]
